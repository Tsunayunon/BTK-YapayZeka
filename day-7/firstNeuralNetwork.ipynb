# %%
x1 = [0,0,1,1]
x2 = [0,1,0,1]
result = []
w1 = 2
w2 = 3


t = int(input("Treshold giriniz:"))
for i in range(4):
    sum = x1[i] * w1 + x2[i] * w2
    result.append(1) if sum >= t else result.append(0)
print(result)
# Out:
# [0, 0, 0, 1]
